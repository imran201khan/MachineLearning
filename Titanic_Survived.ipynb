# %%
import numpy as np
import pandas as pd

# %%
train=pd.read_csv('/content/train (1).csv')
train.sample(10)
# Out:
#      PassengerId  Survived  Pclass  ...     Fare  Cabin  Embarked
# 790          791         0       3  ...   7.7500    NaN         Q
# 315          316         1       3  ...   7.8542    NaN         S
# 111          112         0       3  ...  14.4542    NaN         C
# 809          810         1       1  ...  53.1000     E8         S
# 651          652         1       2  ...  23.0000    NaN         S
# 75            76         0       3  ...   7.6500  F G73         S
# 81            82         1       3  ...   9.5000    NaN         S
# 298          299         1       1  ...  30.5000   C106         S
# 611          612         0       3  ...   7.0500    NaN         S
# 2              3         1       3  ...   7.9250    NaN         S
#
# [10 rows x 12 columns]

# %%
test=pd.read_csv('/content/test (1).csv')
test.sample(5)
# Out:
#      PassengerId  Pclass  ... Cabin Embarked
# 75           967       1  ...  C132        C
# 413         1305       3  ...   NaN        S
# 159         1051       3  ...   NaN        S
# 289         1181       3  ...   NaN        S
# 0            892       3  ...   NaN        Q
#
# [5 rows x 11 columns]

# %%
train.shape
# Out:
# (891, 12)

# %%
test.shape
# Out:
# (418, 11)

# %%
gender=pd.read_csv('/content/gender_submission (2).csv')
gender.sample(10)
# Out:
#      PassengerId  Survived
# 181         1073         0
# 341         1233         0
# 61           953         0
# 95           987         0
# 126         1018         0
# 211         1103         0
# 369         1261         0
# 190         1082         0
# 310         1202         0
# 15           907         1

# %%
gender.shape
# Out:
# (418, 2)

# %%
train.sample(10)
# Out:
#      PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 842          843         1       1  ...  31.0000   NaN         C
# 120          121         0       2  ...  73.5000   NaN         S
# 628          629         0       3  ...   7.8958   NaN         S
# 68            69         1       3  ...   7.9250   NaN         S
# 575          576         0       3  ...  14.5000   NaN         S
# 629          630         0       3  ...   7.7333   NaN         Q
# 821          822         1       3  ...   8.6625   NaN         S
# 96            97         0       1  ...  34.6542    A5         C
# 108          109         0       3  ...   7.8958   NaN         S
# 747          748         1       2  ...  13.0000   NaN         S
#
# [10 rows x 12 columns]

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
train.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
train.describe()
# Out:
#        PassengerId    Survived      Pclass  ...       SibSp       Parch        Fare
# count   891.000000  891.000000  891.000000  ...  891.000000  891.000000  891.000000
# mean    446.000000    0.383838    2.308642  ...    0.523008    0.381594   32.204208
# std     257.353842    0.486592    0.836071  ...    1.102743    0.806057   49.693429
# min       1.000000    0.000000    1.000000  ...    0.000000    0.000000    0.000000
# 25%     223.500000    0.000000    2.000000  ...    0.000000    0.000000    7.910400
# 50%     446.000000    0.000000    3.000000  ...    0.000000    0.000000   14.454200
# 75%     668.500000    1.000000    3.000000  ...    1.000000    0.000000   31.000000
# max     891.000000    1.000000    3.000000  ...    8.000000    6.000000  512.329200
#
# [8 rows x 7 columns]

# %%
train.duplicated().sum()
# Out:
# 0

# %%
train.corr()
# Out:
#              PassengerId  Survived    Pclass  ...     SibSp     Parch      Fare
# PassengerId     1.000000 -0.005007 -0.035144  ... -0.057527 -0.001652  0.012658
# Survived       -0.005007  1.000000 -0.338481  ... -0.035322  0.081629  0.257307
# Pclass         -0.035144 -0.338481  1.000000  ...  0.083081  0.018443 -0.549500
# Age             0.036847 -0.077221 -0.369226  ... -0.308247 -0.189119  0.096067
# SibSp          -0.057527 -0.035322  0.083081  ...  1.000000  0.414838  0.159651
# Parch          -0.001652  0.081629  0.018443  ...  0.414838  1.000000  0.216225
# Fare            0.012658  0.257307 -0.549500  ...  0.159651  0.216225  1.000000
#
# [7 rows x 7 columns]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
train['Pclass'].value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
train['Pclass'].value_counts().plot(kind='bar')

# %%
sns.countplot(train['Pclass'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
train['Pclass'].value_counts().plot(kind='pie',autopct='%.2f')

# %%
train['Survived'].value_counts().plot(kind='bar')

# %%
train['Survived'].value_counts().plot(kind='pie',autopct='%.2f')

# %%
train['SibSp'].value_counts().plot(kind='bar')

# %%
train['Parch'].value_counts().plot(kind='bar')

# %%
sns.boxplot(train['SibSp'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.boxplot(train['Parch'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.distplot(train['Fare'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.boxplot(train['Fare'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
train.sample(5)
# Out:
#      PassengerId  Survived  Pclass  ...      Fare    Cabin  Embarked
# 886          887         0       2  ...   13.0000      NaN         S
# 150          151         0       2  ...   12.5250      NaN         S
# 609          610         1       1  ...  153.4625     C125         S
# 182          183         0       3  ...   31.3875      NaN         S
# 390          391         1       1  ...  120.0000  B96 B98         S
#
# [5 rows x 12 columns]

# %%
#1. Passenger ko delete krna hai
#3. Fare ka <=70 wala value rakhna hai
#4. Age and cabin ka null value k sath deal krni hain and embarked mai 2 null value hai
#5. sex and embarked ko encode krna hai
#6. Since the Ticket attribute has 681 unique tickets, 
#   it will be a bit tricky to convert them into useful categories.
#   So we will drop it from the dataset.

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
train['Embarked'].value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
train['Cabin'].value_counts()
# Out:
# B96 B98        4
# G6             4
# C23 C25 C27    4
# C22 C26        3
# F33            3
#               ..
# E34            1
# C7             1
# C54            1
# E36            1
# C148           1
# Name: Cabin, Length: 147, dtype: int64

# %%
#delete Passenger Id column
train=train.drop(['PassengerId'],axis=1)

# %%
train
# Out:
#      Survived  Pclass  ... Cabin Embarked
# 0           0       3  ...   NaN        S
# 1           1       1  ...   C85        C
# 2           1       3  ...   NaN        S
# 3           1       1  ...  C123        S
# 4           0       3  ...   NaN        S
# ..        ...     ...  ...   ...      ...
# 886         0       2  ...   NaN        S
# 887         1       1  ...   B42        S
# 888         0       3  ...   NaN        S
# 889         1       1  ...  C148        C
# 890         0       3  ...   NaN        Q
#
# [891 rows x 11 columns]

# %%
#encode gender
Genders={'male':1,'female':0}

# %%
data=[train,test]

# %%
for dataset in data:
  dataset['Sex']=dataset['Sex'].map(Genders)

# %%
train
# Out:
#      Survived  Pclass  ... Cabin  Embarked
# 0           0       3  ...   NaN         S
# 1           1       1  ...   C85         C
# 2           1       3  ...   NaN         S
# 3           1       1  ...  C123         S
# 4           0       3  ...   NaN         S
# ..        ...     ...  ...   ...       ...
# 886         0       2  ...   NaN         S
# 887         1       1  ...   B42         S
# 888         0       3  ...   NaN         S
# 889         1       1  ...  C148         C
# 890         0       3  ...   NaN         Q
#
# [891 rows x 11 columns]

# %%
#We will use the Name feature to extract the Titles from the Name,
# so that we can build a new feature out of that.

# %%
data=[train,test]
titles={"Mr":1,"Miss":2,"Mrs":3,"Master":4,"Rare":5}
for dataset in data:
    # extract titles
    dataset['Title'] = dataset.Name.str.extract(' ([A-Za-z]+)\.', expand=False)
    # replace titles with a more common title or as Rare
    dataset['Title'] = dataset['Title'].replace(['Lady', 'Countess','Capt', 'Col','Don', 'Dr',\
                                            'Major', 'Rev', 'Sir', 'Jonkheer', 'Dona'], 'Rare')
    dataset['Title'] = dataset['Title'].replace('Mlle', 'Miss')
    dataset['Title'] = dataset['Title'].replace('Ms', 'Miss')
    dataset['Title'] = dataset['Title'].replace('Mme', 'Mrs')
    # convert titles into numbers
    dataset['Title'] = dataset['Title'].map(titles)
    # filling NaN with 0, to get safe
    dataset['Title'] = dataset['Title'].fillna(0)

# %%
train=train.drop(['Name'],axis=1)
test=test.drop(['Name'],axis=1)

# %%
train.head()
# Out:
#    Survived  Pclass  Sex   Age  ...     Fare  Cabin Embarked  Title
# 0         0       3    1  22.0  ...   7.2500    NaN        S      1
# 1         1       1    0  38.0  ...  71.2833    C85        C      3
# 2         1       3    0  26.0  ...   7.9250    NaN        S      2
# 3         1       1    0  35.0  ...  53.1000   C123        S      3
# 4         0       3    1  35.0  ...   8.0500    NaN        S      1
#
# [5 rows x 11 columns]

# %%
#Since the Ticket attribute has 681 unique tickets, it will be a bit tricky to convert them into useful categories.
# So we will drop it from the dataset.

# %%
train=train.drop(['Ticket'],axis=1)
test=test.drop(['Ticket'],axis=1)

# %%
#fill Missing values in Cabbin
import re
deck = {"A": 1, "B": 2, "C": 3, "D": 4, "E": 5, "F": 6, "G": 7, "U": 8}
data = [train, test]

for dataset in data:
    dataset['Cabin'] = dataset['Cabin'].fillna("U0")
    dataset['Deck'] = dataset['Cabin'].map(lambda x: re.compile("([a-zA-Z]+)").search(x).group())
    dataset['Deck'] = dataset['Deck'].map(deck)
    dataset['Deck'] = dataset['Deck'].fillna(0)
    dataset['Deck'] = dataset['Deck'].astype(int)
# we can now drop the cabin feature
train = train.drop(['Cabin'], axis=1)
test = test.drop(['Cabin'], axis=1)

# %%
train
# Out:
#      Survived  Pclass  Sex   Age  SibSp  Parch     Fare Embarked  Title  Deck
# 0           0       3    1  22.0      1      0   7.2500        S      1     8
# 1           1       1    0  38.0      1      0  71.2833        C      3     3
# 2           1       3    0  26.0      0      0   7.9250        S      2     8
# 3           1       1    0  35.0      1      0  53.1000        S      3     3
# 4           0       3    1  35.0      0      0   8.0500        S      1     8
# ..        ...     ...  ...   ...    ...    ...      ...      ...    ...   ...
# 886         0       2    1  27.0      0      0  13.0000        S      5     8
# 887         1       1    0  19.0      0      0  30.0000        S      2     2
# 888         0       3    0   NaN      1      2  23.4500        S      2     8
# 889         1       1    1  26.0      0      0  30.0000        C      1     3
# 890         0       3    1  32.0      0      0   7.7500        Q      1     8
#
# [891 rows x 10 columns]

# %%
#fiil Age
train['Age_Fill'] = train['Age'].groupby([train['Pclass'], train['Sex']]).apply(lambda x: x.fillna(x.mean()))

# series with filled ages
groupby_result = train.Age_Fill[train.Age.isnull()]

# %%
test['Age_Fill'] = test['Age'].groupby([test['Pclass'], test['Sex']]).apply(lambda x: x.fillna(x.mean()))

# series with filled ages
groupby_result = test.Age_Fill[train.Age.isnull()]

# %%
train['Age_Fill'].isnull().sum()
# Out:
# 0

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Sex       891 non-null    int64
#  3   Age       714 non-null    float64
#  4   SibSp     891 non-null    int64
#  5   Parch     891 non-null    int64
#  6   Fare      891 non-null    float64
#  7   Embarked  889 non-null    object
#  8   Title     891 non-null    int64
#  9   Deck      891 non-null    int64
#  10  Age_Fill  891 non-null    float64
# dtypes: float64(3), int64(7), object(1)
# memory usage: 76.7+ KB

# %%
train=train.drop(['Age'],axis=1)

# %%
test=test.drop(['Age'],axis=1)

# %%
train['Embarked'].value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
train['Embarked'].isnull().sum()
# Out:
# 2

# %%
common_value='S'
data=[train,test]
for dataset in data:
  dataset['Embarked']=dataset['Embarked'].fillna(common_value)

# %%
train.head()
# Out:
#    Survived  Pclass  Sex  SibSp  Parch     Fare Embarked  Title  Deck  Age_Fill
# 0         0       3    1      1      0   7.2500        S      1     8      22.0
# 1         1       1    0      1      0  71.2833        C      3     3      38.0
# 2         1       3    0      0      0   7.9250        S      2     8      26.0
# 3         1       1    0      1      0  53.1000        S      3     3      35.0
# 4         0       3    1      0      0   8.0500        S      1     8      35.0

# %%
ports={'S':0,'C':1,'Q':2}
dataset=[train,test]
for dataset in data:
  dataset['Embarked']=dataset['Embarked'].map(ports)

# %%
train
# Out:
#      Survived  Pclass  Sex  SibSp  ...  Embarked  Title  Deck  Age_Fill
# 0           0       3    1      1  ...         0      1     8     22.00
# 1           1       1    0      1  ...         1      3     3     38.00
# 2           1       3    0      0  ...         0      2     8     26.00
# 3           1       1    0      1  ...         0      3     3     35.00
# 4           0       3    1      0  ...         0      1     8     35.00
# ..        ...     ...  ...    ...  ...       ...    ...   ...       ...
# 886         0       2    1      0  ...         0      5     8     27.00
# 887         1       1    0      0  ...         0      2     2     19.00
# 888         0       3    0      1  ...         0      2     8     21.75
# 889         1       1    1      0  ...         1      1     3     26.00
# 890         0       3    1      0  ...         2      1     8     32.00
#
# [891 rows x 10 columns]

# %%
test
# Out:
#      PassengerId  Pclass  Sex  SibSp  ...  Embarked  Title  Deck   Age_Fill
# 0            892       3    1      0  ...         2      1     8  34.500000
# 1            893       3    0      1  ...         0      3     8  47.000000
# 2            894       2    1      0  ...         2      1     8  62.000000
# 3            895       3    1      0  ...         0      1     8  27.000000
# 4            896       3    0      1  ...         0      3     8  22.000000
# ..           ...     ...  ...    ...  ...       ...    ...   ...        ...
# 413         1305       3    1      0  ...         0      1     8  24.525104
# 414         1306       1    0      0  ...         1      5     3  39.000000
# 415         1307       3    1      0  ...         0      1     8  38.500000
# 416         1308       3    1      0  ...         0      1     8  24.525104
# 417         1309       3    1      1  ...         1      4     8  24.525104
#
# [418 rows x 10 columns]

# %%
#Building ML model
x_train=train.drop(['Survived'],axis=1)

# %%
y_train=train['Survived']

# %%
x_test=test.drop(['PassengerId'],axis=1)

# %%
# Algorithms
from sklearn import linear_model
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import Perceptron
from sklearn.linear_model import SGDClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC, LinearSVC
from sklearn.naive_bayes import GaussianNB

# %%
LR=LogisticRegression()

# %%
LR.fit(x_train,y_train)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# LogisticRegression()

# %%
x_test=x_test.drop(['Name'],axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-226-0ab6444b1138> in <module>()
# ----> 1 x_test=x_test.drop(['Name'],axis=1)
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4911             level=level,
#    4912             inplace=inplace,
# -> 4913             errors=errors,
#    4914         )
#    4915
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4148         for axis, labels in axes.items():
# ...

# %%
def clean_dataset(x_test):
    assert isinstance(x_test, pd.DataFrame), "df needs to be a pd.DataFrame"
    x_test.dropna(inplace=True)
    indices_to_keep = ~x_test.isin([np.nan, np.inf, -np.inf]).any(1)
    return x_test[indices_to_keep].astype(np.float64)

# %%
x_test=clean_dataset(x_test)

# %%
x_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 417 entries, 0 to 417
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Pclass    417 non-null    float64
#  1   Sex       417 non-null    float64
#  2   SibSp     417 non-null    float64
#  3   Parch     417 non-null    float64
#  4   Fare      417 non-null    float64
#  5   Embarked  417 non-null    float64
#  6   Title     417 non-null    float64
#  7   Deck      417 non-null    float64
#  8   Age_Fill  417 non-null    float64
# dtypes: float64(9)
# memory usage: 32.6 KB

# %%
y_pred=LR.predict(x_test)

# %%
acc_log = round(LR.score(x_train, y_train) * 100, 2)
acc_log
# Out:
# 81.26
